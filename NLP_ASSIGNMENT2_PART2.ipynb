# %%
import re
import csv

def parse_date(text: str) -> str | None:
    month_map = {
        'january': '01', 'jan': '01',
        'february': '02', 'feb': '02',
        'march': '03', 'mar': '03',
        'april': '04', 'apr': '04',
        'may': '05',
        'june': '06', 'jun': '06',
        'july': '07', 'jul': '07',
        'august': '08', 'aug': '08',
        'september': '09', 'sep': '09', 'sept': '09',
        'october': '10', 'oct': '10',
        'november': '11', 'nov': '11',
        'december': '12', 'dec': '12',
    }

    # Create a regex pattern string from the month_map keys for matching month names.
    month_names_pattern = '|'.join(month_map.keys())

    # A list of regex patterns to try in order of precedence.
    # Named groups (?P<name>...) are used to easily extract date components.
    patterns = [
        # Pattern 1: Handles "21st June, 2024", "11 August 2024", "3rd of March 1998"
        re.compile(
            r'\b(?P<day>\d{1,2})(?:st|nd|rd|th)?(?:\s+of)?\s+(?P<month>' + month_names_pattern + r')[,.]?\s+(?P<year>\d{4})\b',
            re.IGNORECASE
        ),
        # Pattern 2: Handles "June 21st, 2024", "August 11, 2024"
        re.compile(
            r'\b(?P<month>' + month_names_pattern + r')\s+(?P<day>\d{1,2})(?:st|nd|rd|th)?[,.]?\s+(?P<year>\d{4})\b',
            re.IGNORECASE
        ),
        # Pattern 3: Handles "DD/MM/YYYY", "DD-MM-YYYY", "DD.MM.YYYY"
        re.compile(r'\b(?P<day>\d{1,2})[/\.-](?P<month>\d{1,2})[/\.-](?P<year>\d{4})\b'),
        # Pattern 4: Handles "YYYY-MM-DD", "YYYY/MM/DD", "YYYY.MM.DD"
        re.compile(r'\b(?P<year>\d{4})[/\.-](?P<month>\d{1,2})[/\.-](?P<day>\d{1,2})\b'),
        # Pattern 5: Handles "DD/MM/YY", "DD-MM-YY"
        re.compile(r'\b(?P<day>\d{1,2})[/\.-](?P<month>\d{1,2})[/\.-](?P<year>\d{2})\b'),
        # Pattern 6: Handles "YY/MM/DD", "YY-MM-DD"
        re.compile(r'\b(?P<year>\d{2})[/\.-](?P<month>\d{1,2})[/\.-](?P<day>\d{1,2})\b'),
    ]

    for pattern in patterns:
        match = pattern.search(text)
        if match:
            parts = match.groupdict()
            day_str = parts.get('day')
            month_str = parts.get('month')
            year_str = parts.get('year')

            # Handle 2-digit years by converting them to 4-digit years
            if len(year_str) == 2:
                year_val_2_digit = int(year_str)
                # Heuristic: years > current_year_last_two_digits+10 are 19xx, else 20xx.
                # This is a simple rule; for this script, we'll use a fixed cutoff.
                # e.g., > 30 is 19xx, <= 30 is 20xx. Handles 1931-2030.
                if year_val_2_digit > 30:
                    year_str = f"19{year_str}"
                else:
                    year_str = f"20{year_str}"

            if month_str and not month_str.isdigit():
                month_num_str = month_map.get(month_str.lower())
            else:
                month_num_str = month_str

            try:
                day_val = int(day_str)
                month_val = int(month_num_str)
                if not (1 <= day_val <= 31 and 1 <= month_val <= 12):
                    continue
            except (ValueError, TypeError):
                continue

            return f"{day_val:02d}/{month_val:02d}/{year_str}"

    return None

# %%
# --- Main execution block to test the function using the provided CSV ---
if __name__ == "__main__":
    csv_file_name = 'date_parser_testcases.csv'
    inputs = []
    expected_outputs = []

    try:
        with open(csv_file_name, mode='r', encoding='utf-8') as infile:
            # Use DictReader to easily access columns by name
            reader = csv.DictReader(infile)
            for row in reader:
                # Check for variations in column names (e.g., with/without spaces)
                input_col = 'Input' if 'Input' in row else 'Input '
                expected_col = 'Expected Output' if 'Expected Output' in row else 'Expected Output '

                if input_col in row and expected_col in row:
                    inputs.append(row[input_col])
                    expected_outputs.append(row[expected_col])
    except FileNotFoundError:
        print(f"Error: The file '{csv_file_name}' was not found.")
        print("Please make sure the CSV file is in the same directory as the script.")
    except Exception as e:
        print(f"An error occurred while reading the CSV file: {e}")

    if inputs:
        print(f"--- Running Date Parser Test Cases from '{csv_file_name}' ---\n")
        correct_count = 0
        for i, text_input in enumerate(inputs):
            parsed_result = parse_date(text_input)
            expected_result = expected_outputs[i]

             status = "PASS" if parsed_result == expected_result else "FAIL"
             if status == "PASS":
                correct_count += 1

            print(f"{i+1}. Input:    \"{text_input}\"")
            print(f"   Output:   {parsed_result}\n")
            print(f" Expected Output: {}

        total_count = len(inputs)
        accuracy = (correct_count / total_count) * 100 if total_count > 0 else 0
    else:
        print("No test cases were loaded. Please check the CSV file.")
# Out:
# --- Running Date Parser Test Cases from 'date_parser_testcases.csv' ---
#
# 1. Input:    "The event will take place on March 5, 2023."
#    Output:   05/03/2023
#
# 2. Input:    "Her birthday is on 07/08/1990."
#    Output:   07/08/1990
#
# 3. Input:    "The deadline is 2022-12-31."
#    Output:   31/12/2022
#
# 4. Input:    "We met on 1st of January 2000."
#    Output:   01/01/2000
#
# 5. Input:    "The concert is scheduled for 15th September, 2021."
#    Output:   15/09/2021
#
# 6. Input:    "Let's catch up on 02.04.2022."
#    Output:   02/04/2022
#
# 7. Input:    "The project started on 5/6/19."
#    Output:   05/06/2019
#
# 8. Input:    "He was born on 1987/11/23."
#    Output:   23/11/1987
#
# 9. Input:    "Christmas is on 25th Dec 2024."
#    Output:   25/12/2024
#
# 10. Input:    "The meeting is set for April 03, 2020."
#    Output:   03/04/2020
#
# 11. Input:    "Her birthdate, noted as 1997-05-20, is in the records."
#    Output:   20/05/1997
#
# 12. Input:    "Her appointment is on the 2nd of March, 2021."
#    Output:   02/03/2021
#
# 13. Input:    "The exam date is 2021.11.10."
#    Output:   10/11/2021
#
# 14. Input:    "They got married on 12/12/12."
#    Output:   12/12/2012
#
# 15. Input:    "The workshop is on February 15th, 2022."
#    Output:   15/02/2022
#
# 16. Input:    "Submit your report by 08/31/2021."
#    Output:   None
#
# 17. Input:    "The course starts on 1st July 2023."
#    Output:   01/07/2023
#
# 18. Input:    "Independence Day is on 4th of July, 2022."
#    Output:   04/07/2022
#
# 19. Input:    "His birthday is 1995/10/30."
#    Output:   30/10/1995
#
# 20. Input:    "The new year begins on 01-01-2023."
#    Output:   01/01/2023
#
# 21. Input:    "The seminar is on 03/14/2022."
#    Output:   None
#
# 22. Input:    "My last day is 31.08.2020."
#    Output:   31/08/2020
#
# 23. Input:    "The due date is 2020-02-28."
#    Output:   28/02/2020
#
# 24. Input:    "The holiday starts on Dec 20th, 2021."
#    Output:   20/12/2021
#
# 25. Input:    "The conference will be held on 5th May 2023."
#    Output:   05/05/2023
#
# 26. Input:    "They moved in on 12/25/2019."
#    Output:   None
#
# 27. Input:    "The festival begins on March 17, 2022."
#    Output:   17/03/2022
#
# 28. Input:    "The ceremony is on 11.11.2021."
#    Output:   11/11/2021
#
# 29. Input:    "The event is on 2023/07/04."
#    Output:   04/07/2023
#
# 30. Input:    "Her graduation is on May 30th, 2022."
#    Output:   30/05/2022
#
# 31. Input:    "The release date is 2021-09-09."
#    Output:   09/09/2021
#
# 32. Input:    "The interview is on 1/2/2022."
#    Output:   01/02/2022
#
# 33. Input:    "The celebration is on 2022-10-10."
#    Output:   10/10/2022
#
# 34. Input:    "His wedding is on 6th of August, 2020."
#    Output:   06/08/2020
#
# 35. Input:    "She was born on 3rd March 1998."
#    Output:   03/03/1998
#
# 36. Input:    "The opening is on 10/10/2018."
#    Output:   10/10/2018
#
# 37. Input:    "The deadline is 2020.12.15."
#    Output:   15/12/2020
#
# 38. Input:    "The party is on 31-12-2022."
#    Output:   31/12/2022
#
# 39. Input:    "The workshop is on February 29, 2024."
#    Output:   29/02/2024
#
# 40. Input:    "Vacation starts on 07/15/2021."
#    Output:   None
#
# 41. Input:    "The application is due by 2022-03-03."
#    Output:   03/03/2022
#
# 42. Input:    "The tournament is on June 1st, 2021."
#    Output:   01/06/2021
#
# 43. Input:    "The closing date is 08/08/2020."
#    Output:   08/08/2020
#
# 44. Input:    "The concert is on 2020/09/09."
#    Output:   09/09/2020
#
# 45. Input:    "The exam is on 01.01.2022."
#    Output:   01/01/2022
#
# 46. Input:    "Independence Day is 2023-07-04."
#    Output:   04/07/2023
#
# 47. Input:    "The last date is 30th November 2022."
#    Output:   30/11/2022
#
# 48. Input:    "The conference is on 15th October 2023."
#    Output:   15/10/2023
#
# 49. Input:    "His birthdate is 1990-05-20."
#    Output:   20/05/1990
#
# 50. Input:    "The festival is on 12th August 2024."
#    Output:   12/08/2024
#
# 51. Input:    "Input"
#    Output:   None
#
# 52. Input:    "We are planning to meet on March 5, 2023, for lunch."
#    Output:   05/03/2023
#
# 53. Input:    "Her birthday, which she celebrates on 07/08/1990, is coming up soon."
#    Output:   07/08/1990
#
# 54. Input:    "The deadline, unfortunately, is set to 2022-12-31."
#    Output:   31/12/2022
#
# 55. Input:    "We first met on the 1st of January 2000 at the conference."
#    Output:   01/01/2000
#
# 56. Input:    "The concert, happening on 15th September 2021, will be amazing."
#    Output:   15/09/2021
#
# 57. Input:    "Remember, the meeting is on 02.04.2022 at 10 AM."
#    Output:   02/04/2022
#
# 58. Input:    "Let's wrap up the project by 5/6/19, so we can relax."
#    Output:   05/06/2019
#
# 59. Input:    "His birth date, recorded as 1987/11/23, was a memorable day."
#    Output:   23/11/1987
#
# 60. Input:    "We celebrate Christmas every year on 25th Dec, including 2024."
#    Output:   None
#
# 61. Input:    "The meeting is rescheduled to April 03, 2020, as per the latest update."
#    Output:   03/04/2020
#
# 62. Input:    "Their anniversary is marked on the 2nd of March, 2021."
#    Output:   02/03/2021
#
# 63. Input:    "The official exam date is now 2021.11.10, per the new schedule."
#    Output:   10/11/2021
#
# 64. Input:    "They celebrated their wedding on 12/12/12 in grand style."
#    Output:   12/12/2012
#
# 65. Input:    "Our next workshop is scheduled for February 15th, 2022."
#    Output:   15/02/2022
#
# 66. Input:    "The submission deadline, noted as 08/31/2021, is fast approaching."
#    Output:   None
#
# 67. Input:    "The course officially begins on 1st July 2023."
#    Output:   01/07/2023
#
# 68. Input:    "We celebrate Independence Day on the 4th of July every year, including 2022."
#    Output:   None
#
# 69. Input:    "He mentioned that his birth date is 1995/10/30 in the form."
#    Output:   30/10/1995
#
# 70. Input:    "The new year's celebration begins on 01-01-2023 at midnight."
#    Output:   01/01/2023
#
# 71. Input:    "We scheduled the seminar for 03/14/2022, don't forget."
#    Output:   None
#
# 72. Input:    "My final working day here is noted as 31.08.2020."
#    Output:   31/08/2020
#
# 73. Input:    "The project's due date is officially 2020-02-28."
#    Output:   28/02/2020
#
# 74. Input:    "The holiday vacation starts on Dec 20th, 2021, for everyone."
#    Output:   20/12/2021
#
# 75. Input:    "The conference, marked for 5th May 2023, is a significant event."
#    Output:   05/05/2023
#
# 76. Input:    "They officially moved in on 12/25/2019."
#    Output:   None
#
# 77. Input:    "Our festival starts on March 17, 2022, with a parade."
#    Output:   17/03/2022
#
# 78. Input:    "The ceremony date is fixed as 11.11.2021."
#    Output:   11/11/2021
#
# 79. Input:    "The big event is planned for 2023/07/04, so mark your calendars."
#    Output:   04/07/2023
#
# 80. Input:    "Her graduation day is set for May 30th, 2022."
#    Output:   30/05/2022
#
# 81. Input:    "The software release date is set for 2021-09-09."
#    Output:   09/09/2021
#
# 82. Input:    "The job interview is on 1/2/2022, don't be late."
#    Output:   01/02/2022
#
# 83. Input:    "The grand celebration is on 2022-10-10, a date to remember."
#    Output:   10/10/2022
#
# 84. Input:    "The wedding is on 6th of August, 2020, in the evening."
#    Output:   06/08/2020
#
# 85. Input:    "She mentioned she was born on the 3rd of March 1998."
#    Output:   03/03/1998
#
# 86. Input:    "The official opening date is 10/10/2018, as per the announcement."
#    Output:   10/10/2018
#
# 87. Input:    "The critical deadline is 2020.12.15, please note it."
#    Output:   15/12/2020
#
# 88. Input:    "The New Year's Eve party is on 31-12-2022, join us!"
#    Output:   31/12/2022
#
# 89. Input:    "The next workshop is on February 29, 2024, due to the leap year."
#    Output:   29/02/2024
#
# 90. Input:    "Vacation officially starts on 07/15/2021, get ready."
#    Output:   None
#
# 91. Input:    "The application submission date is 2022-03-03."
#    Output:   03/03/2022
#
# 92. Input:    "The tournament begins on June 1st, 2021, early in the morning."
#    Output:   01/06/2021
#
# 93. Input:    "The registration closing date is 08/08/2020."
#    Output:   08/08/2020
#
# 94. Input:    "The music concert is scheduled for 2020/09/09."
#    Output:   09/09/2020
#
# 95. Input:    "The exam will be held on 01.01.2022, start preparing."
#    Output:   01/01/2022
#
# 96. Input:    "We celebrate Independence Day on 2023-07-04, as always."
#    Output:   04/07/2023
#
# 97. Input:    "The final date for submission is 30th November 2022."
#    Output:   30/11/2022
#
# 98. Input:    "The annual conference is on 15th October 2023, mark your calendars."
#    Output:   15/10/2023
#
# 99. Input:    "His birthdate, noted as 1990-05-20, is in the records."
#    Output:   20/05/1990
#
# 100. Input:    "The festival will be celebrated on 12th August 2024, with grand events."
#    Output:   12/08/2024
